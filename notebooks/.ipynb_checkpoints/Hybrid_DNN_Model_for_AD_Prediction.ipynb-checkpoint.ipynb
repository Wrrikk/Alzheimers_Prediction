# %% [markdown]
# # Hybrid DNN Model for Alzheimer's Disease Prediction
#
# Alzheimer's disease (AD) is a chronic neurodegenerative disease that represents a significant and growing global health challenge. Early and accurate diagnosis is crucial for management and treatment planning, but it remains a complex task due to the multifactorial nature of the disease.
#
# In this notebook, we develop a hybrid deep neural network (DNN) model aimed at predicting the onset and progression of Alzheimer's disease. The "hybrid" aspect of the model refers to its combination of high-capacity deep learning techniques with feature importance analysis, leveraging both data-driven predictions and interpretability.
#
# The goals of this project are:
# - To build a robust predictive model capable of identifying patterns associated with AD progression using patient data.
# - To utilize feature importance analysis, specifically through SHapley Additive exPlanations (SHAP), to gain insights into which features contribute most significantly to the model's predictions.
# - To evaluate the model's performance through rigorous metrics, ensuring its reliability and applicability in a clinical setting.
#
# Through this notebook, we document the entire process from data preprocessing, model construction, and training to the interpretation of the model outputs. Our approach underscores the importance of not only predictive accuracy but also the transparency and interpretability of machine learning models in healthcare.

# %% [markdown]
# ## Import Libraries
#
# This section loads the necessary Python libraries and modules required for processing the data, building, training, and evaluating the deep neural network model, and interpreting its predictions:
#
# - **NumPy** and **Pandas**: For numerical operations and data manipulation.
# - **TensorFlow and Keras**: For building and training the deep neural network.
# - **SHAP**: For interpreting the model's predictions through SHapley Additive exPlanations.
# - **Scikit-learn**: Provides tools for data preprocessing, cross-validation, and pipeline creation.
# - **os**: To handle directory and file operations, crucial for model saving and logging.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import shap
import os
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.model_selection import KFold
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.externals import joblib
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.utils import to_categorical
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %% [markdown]
# ## Load the Dataset
#
# The dataset is loaded from a CSV file located at `../data/Main.csv`. This dataset contains the data necessary for training and evaluating the Alzheimer's Disease prediction model. It includes various features such as clinical assessments, biomarker data, and imaging data from individuals assessed for Alzheimer's Disease.

# %%
# Load the dataset from a CSV file
data_path = "../data/Main.csv"
data = pd.read_csv(data_path)

# %% [markdown]
# ## Data Preprocessing
#
# In this section, we prepare the dataset for the modeling phase:
#
# ### Separate Target and Features
# The target variable, 'DX.bl', which represents the diagnostic outcome, is separated from the feature set. This allows for a clear distinction between input features and the output we aim to predict.
#
# ### Identify Feature Types
# The features are categorized into numerical and categorical types. Numerical columns are those that contain quantitative data, while categorical columns contain qualitative data. This distinction is crucial for applying appropriate preprocessing techniques.
#
# ### Preprocessing Steps
# A preprocessing pipeline is established for both types of data:
# - **Numerical Features**: Missing values are imputed using the median of the column, and data is scaled using standard scaling to normalize the feature values.
# - **Categorical Features**: Missing values are filled using the most frequent category, and the categories are then encoded using one-hot encoding to transform them into a format suitable for the model.
#
# The preprocessing steps ensure that the data fed into the model is clean and appropriately formatted, enhancing model performance and stability.
#
# ### Convert Processed Data for Model Input
# After applying the preprocessing steps, the processed data is converted into a dense array format, making it compatible for input into the machine learning model.
#
# ### Feature Names Collection
# Post-preprocessing, the names of the new numerical and categorical features are collected for future reference, especially useful during feature importance analysis and model interpretation.

# %%
# Separate the target variable 'DX.bl' from the features
y = data['DX.bl']
X = data.drop(['DX.bl'], axis=1)

# Identify numerical and categorical columns
numerical_cols = X.select_dtypes(include=['number']).columns
categorical_cols = X.select_dtypes(exclude=['number']).columns

# Create preprocessing steps for numerical and categorical data
preprocessor = ColumnTransformer(
    transformers=[
        ('num', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='median')),
            ('scaler', StandardScaler())
        ]), numerical_cols),
        ('cat', Pipeline(steps=[
            ('imputer', SimpleImputer(strategy='most_frequent')),
            ('encoder', OneHotEncoder(handle_unknown='ignore'))
        ]), categorical_cols)
    ]
)

# Apply the preprocessing pipeline to the feature data and convert to a dense array
X_processed = preprocessor.fit_transform(X).toarray()

# Get feature names for the processed columns
new_numerical_features = numerical_cols.tolist()
new_categorical_features = preprocessor.named_transformers_['cat']['encoder'].get_feature_names_out(categorical_cols).tolist()
new_features = new_numerical_features + new_categorical_features
joblib.dump(preprocessor, '../models/preprocessor.joblib')  # Save feature transformer

# %% [markdown]
# ## Encoding the Target Variable
#
# The target variable requires encoding to transform it from categorical labels into a numerical format that can be processed by the neural network:
#
# ### Label Encoding
# First, the target variable 'DX.bl' is transformed using Label Encoding. This converts each unique label into a specific integer. This step is crucial for preparing categorical labels for further encoding techniques and ensuring compatibility with various machine learning algorithms.
#
# ### One-Hot Encoding for Multiclass Classification
# If the prediction task involves multiclass classification (i.e., predicting more than two classes), the integer-encoded labels are further transformed using One-Hot Encoding. This process converts the integer labels into a binary matrix representation. Each column in this matrix represents one category of the data, with only one active state (`1`) per row, indicating the presence of a particular class. This method is essential for models that require a clear distinction between multiple classes, enhancing the model's ability to classify accurately.
#
# The resulting encoded labels (`y_onehot`) are now ready for use in training the deep learning model, providing a clear and effective way for the network to predict multiple classes.

# %%
# Encode the target variable for classification
le = LabelEncoder()
y_encoded = le.fit_transform(y)

# If the task is multiclass classification, use one-hot encoding
y_onehot = to_categorical(y_encoded)
joblib.dump(le, '../models/label_encoder.joblib')

# %% [markdown]
# ## Data Splitting for Model Training and Evaluation
#
# To ensure the robustness of the model and evaluate its performance effectively, the dataset is split into training, validation, and test sets:
#
# ### Training and Test Split
# The data is initially split into training and test sets, with 20% of the data reserved for the test set. This split is controlled by a random state to ensure reproducibility of the results. The test set will be used to evaluate the model's performance after it has been trained and validated, providing an unbiased assessment of its generalization capability.
#
# ### Training and Validation Split
# The training data is further divided to include a validation set, which accounts for 25% of the training data. This validation set is crucial for tuning the model's parameters and preventing overfitting. It provides a reliable dataset for validating the model's performance during training, allowing adjustments before the final evaluation on the test set.
#
# These splits help in training a well-generalized model and ensure that the performance metrics reflect how well the model can perform on unseen data.

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_processed, y_onehot, test_size=0.2, random_state=42)
# Further split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=42)

# %% [markdown]
# ## Model Architecture Definition
#
# This section defines the architecture of the deep neural network used for predicting Alzheimer's Disease. The function `create_model` sets up a sequential model with multiple dense layers and dropout layers to prevent overfitting:
#
# - **Input Layer**: Specifies the number of features the model will accept.
# - **Hidden Layers**: Includes three hidden layers with decreasing units (128, 64, 32) using ReLU activation to introduce non-linearity.
# - **Dropout Layers**: Placed after each hidden layer to reduce overfitting by randomly setting a fraction of input units to 0 during training.
# - **Output Layer**: Uses a softmax activation function to output probabilities across the `num_classes`, suitable for multiclass classification.
#
# The model is compiled with the Adam optimizer and categorical crossentropy loss function, which is appropriate for multiclass classification tasks.

# %%
def create_model(input_shape, num_classes):
    # Initialize a sequential model and add layers
    model = Sequential([
        Input(shape=(input_shape,)),
        Dense(128, activation='relu'),  # First hidden layer with ReLU activation
        Dropout(0.2),  # Dropout to prevent overfitting
        Dense(64, activation='relu'),  # Second hidden layer
        Dropout(0.2),  # Another dropout layer
        Dense(32, activation='relu'),  # Third hidden layer
        Dropout(0.2),  # Final dropout layer
        Dense(num_classes, activation='softmax')  # Output layer with softmax activation for multiclass classification
    ])
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# %% [markdown]
# ## K-Fold Cross-Validation for Model Evaluation
#
# To ensure the model's robustness and generalizability, k-fold cross-validation is employed. This method enhances the validation process by dividing the data into `k` subsets and iteratively training the model `k` times. Each time, one subset is used as the test set and the others as the training set.
#
# ### Setup
# - **Number of Folds**: 5 (This helps in reducing the variance of the model's performance estimates.)
# - **Shuffling**: Data is shuffled to ensure random distribution across folds.
# - **Random State**: Fixed to ensure reproducibility of results.
#
# ### Model Training and Validation Loop
# - For each fold, a fresh instance of the model is created and compiled.
# - Training is monitored with an Early Stopping callback to halt training if the validation loss does not improve, thus preventing overfitting.
# - A ModelCheckpoint callback is used to save the best version of the model for each fold based on the minimum validation loss.
#
# ### Model Evaluation
# - After training, each model is evaluated on its respective test fold.
# - The loss and accuracy for each fold are recorded and reported.
#
# ### Results
# - After all folds are processed, the average and standard deviation of the accuracy and loss across all folds are computed and displayed. This provides a comprehensive view of the model’s performance and its variability across different subsets of the data.
#
# The use of k-fold cross-validation in this context is particularly valuable in assessing the model's ability to generalize to new data, an essential aspect of a reliable predictive model in healthcare.

# %%
num_folds = 5
kfold = KFold(n_splits=num_folds, shuffle=True, random_state=42)

# Define the base directory where the models will be saved
models_dir = "../models"
os.makedirs(models_dir, exist_ok=True)  

fold_no = 1
loss_per_fold = []
accuracy_per_fold = []

for train, test in kfold.split(X_processed, y_onehot):
    # Create and compile the model
    model = create_model(X_processed.shape[1], y_onehot.shape[1])

    # Setup callbacks
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True, verbose=1)
    
    # Define the path for the ModelCheckpoint
    filepath = os.path.join(models_dir, f'best_model_fold_{fold_no}.h5')
    
    model_checkpoint = ModelCheckpoint(filepath, save_best_only=True, monitor='val_loss', mode='min', verbose=1)

    print(f'Training for fold {fold_no} ...')
    history = model.fit(X_processed[train], y_onehot[train],
                        batch_size=32,
                        epochs=100,
                        validation_data=(X_processed[test], y_onehot[test]),
                        callbacks=[early_stopping, model_checkpoint],
                        verbose=2)

    # Evaluate the model
    scores = model.evaluate(X_processed[test], y_onehot[test], verbose=0)
    print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
    loss_per_fold.append(scores[0])
    accuracy_per_fold.append(scores[1] * 100)

    fold_no += 1

print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(accuracy_per_fold):.2f}% (+- {np.std(accuracy_per_fold):.2f})')
print(f'> Loss: {np.mean(loss_per_fold):.2f}')
print('------------------------------------------------------------------------')
# Out:
# Training for fold 1 ...
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.17410, saving model to ../models\best_model_fold_1.h5
# 279/279 - 4s - loss: 0.5940 - accuracy: 0.7815 - val_loss: 0.1741 - val_accuracy: 0.9300 - 4s/epoch - 13ms/step
# Epoch 2/100
# You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
# Epoch 2: val_loss improved from 0.17410 to 0.09509, saving model to ../models\best_model_fold_1.h5
# 279/279 - 2s - loss: 0.1598 - accuracy: 0.9467 - val_loss: 0.0951 - val_accuracy: 0.9700 - 2s/epoch - 8ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.09509 to 0.04687, saving model to ../models\best_model_fold_1.h5
# 279/279 - 2s - loss: 0.0770 - accuracy: 0.9744 - val_loss: 0.0469 - val_accuracy: 0.9857 - 2s/epoch - 8ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.04687 to 0.03159, saving model to ../models\best_model_fold_1.h5
# 279/279 - 2s - loss: 0.0348 - accuracy: 0.9904 - val_loss: 0.0316 - val_accuracy: 0.9910 - 2s/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 0.03159
# 279/279 - 2s - loss: 0.0220 - accuracy: 0.9935 - val_loss: 0.0377 - val_accuracy: 0.9843 - 2s/epoch - 8ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.03159
# 279/279 - 2s - loss: 0.0311 - accuracy: 0.9904 - val_loss: 0.0715 - val_accuracy: 0.9794 - 2s/epoch - 8ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 0.03159 to 0.01843, saving model to ../models\best_model_fold_1.h5
# 279/279 - 2s - loss: 0.0249 - accuracy: 0.9920 - val_loss: 0.0184 - val_accuracy: 0.9933 - 2s/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.01843
# 279/279 - 2s - loss: 0.0146 - accuracy: 0.9960 - val_loss: 0.0439 - val_accuracy: 0.9852 - 2s/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.01843
# 279/279 - 2s - loss: 0.0091 - accuracy: 0.9980 - val_loss: 0.0233 - val_accuracy: 0.9928 - 2s/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.01843 to 0.01478, saving model to ../models\best_model_fold_1.h5
# 279/279 - 2s - loss: 0.0135 - accuracy: 0.9969 - val_loss: 0.0148 - val_accuracy: 0.9942 - 2s/epoch - 8ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0192 - accuracy: 0.9941 - val_loss: 0.0520 - val_accuracy: 0.9870 - 2s/epoch - 8ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0085 - accuracy: 0.9978 - val_loss: 0.0552 - val_accuracy: 0.9874 - 2s/epoch - 8ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0090 - accuracy: 0.9971 - val_loss: 0.0241 - val_accuracy: 0.9924 - 2s/epoch - 8ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0035 - accuracy: 0.9990 - val_loss: 0.0154 - val_accuracy: 0.9960 - 2s/epoch - 8ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0107 - accuracy: 0.9980 - val_loss: 0.0336 - val_accuracy: 0.9892 - 2s/epoch - 8ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.0206 - val_accuracy: 0.9924 - 2s/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0091 - accuracy: 0.9982 - val_loss: 0.0166 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.01478
# 279/279 - 2s - loss: 0.0125 - accuracy: 0.9966 - val_loss: 0.0237 - val_accuracy: 0.9933 - 2s/epoch - 9ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.01478 to 0.01369, saving model to ../models\best_model_fold_1.h5
# 279/279 - 3s - loss: 0.0029 - accuracy: 0.9993 - val_loss: 0.0137 - val_accuracy: 0.9978 - 3s/epoch - 9ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0204 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0168 - accuracy: 0.9964 - val_loss: 0.0421 - val_accuracy: 0.9888 - 2s/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0118 - accuracy: 0.9964 - val_loss: 0.0323 - val_accuracy: 0.9901 - 2s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0025 - accuracy: 0.9991 - val_loss: 0.0287 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0130 - accuracy: 0.9973 - val_loss: 0.0687 - val_accuracy: 0.9830 - 2s/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0035 - accuracy: 0.9996 - val_loss: 0.0150 - val_accuracy: 0.9973 - 2s/epoch - 8ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0050 - accuracy: 0.9989 - val_loss: 0.0202 - val_accuracy: 0.9933 - 2s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0127 - accuracy: 0.9971 - val_loss: 0.0207 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0123 - accuracy: 0.9967 - val_loss: 0.0158 - val_accuracy: 0.9951 - 2s/epoch - 8ms/step
# Epoch 29/100
# Restoring model weights from the end of the best epoch: 19.
#
# Epoch 29: val_loss did not improve from 0.01369
# 279/279 - 2s - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0407 - val_accuracy: 0.9924 - 2s/epoch - 9ms/step
# Epoch 29: early stopping
# Score for fold 1: loss of 0.013690964318811893; accuracy of 99.77578520774841%
# Training for fold 2 ...
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.17853, saving model to ../models\best_model_fold_2.h5
# 279/279 - 4s - loss: 0.5775 - accuracy: 0.7863 - val_loss: 0.1785 - val_accuracy: 0.9323 - 4s/epoch - 14ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.17853 to 0.08390, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.1598 - accuracy: 0.9424 - val_loss: 0.0839 - val_accuracy: 0.9717 - 2s/epoch - 9ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.08390 to 0.04338, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0675 - accuracy: 0.9796 - val_loss: 0.0434 - val_accuracy: 0.9861 - 2s/epoch - 9ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.04338 to 0.03145, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0403 - accuracy: 0.9883 - val_loss: 0.0315 - val_accuracy: 0.9906 - 2s/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.03145 to 0.02285, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0212 - accuracy: 0.9935 - val_loss: 0.0228 - val_accuracy: 0.9924 - 2s/epoch - 8ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.02285 to 0.02009, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0119 - accuracy: 0.9967 - val_loss: 0.0201 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.02009
# 279/279 - 2s - loss: 0.0231 - accuracy: 0.9941 - val_loss: 0.0425 - val_accuracy: 0.9852 - 2s/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.02009
# 279/279 - 2s - loss: 0.0177 - accuracy: 0.9948 - val_loss: 0.0225 - val_accuracy: 0.9924 - 2s/epoch - 7ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.02009
# 279/279 - 2s - loss: 0.0187 - accuracy: 0.9943 - val_loss: 0.0222 - val_accuracy: 0.9933 - 2s/epoch - 8ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 0.02009 to 0.01550, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0187 - accuracy: 0.9944 - val_loss: 0.0155 - val_accuracy: 0.9960 - 2s/epoch - 8ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.01550
# 279/279 - 2s - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.0159 - val_accuracy: 0.9964 - 2s/epoch - 8ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.01550
# 279/279 - 2s - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0475 - val_accuracy: 0.9857 - 2s/epoch - 8ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.01550 to 0.01496, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0155 - accuracy: 0.9956 - val_loss: 0.0150 - val_accuracy: 0.9964 - 2s/epoch - 8ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.01496
# 279/279 - 2s - loss: 0.0161 - accuracy: 0.9953 - val_loss: 0.0213 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.01496
# 279/279 - 2s - loss: 0.0114 - accuracy: 0.9965 - val_loss: 0.0326 - val_accuracy: 0.9919 - 2s/epoch - 7ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.01496
# 279/279 - 2s - loss: 0.0087 - accuracy: 0.9972 - val_loss: 0.0297 - val_accuracy: 0.9924 - 2s/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 0.01496 to 0.01064, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0106 - val_accuracy: 0.9969 - 2s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.01064 to 0.00971, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0097 - val_accuracy: 0.9987 - 2s/epoch - 8ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.00971
# 279/279 - 2s - loss: 0.0174 - accuracy: 0.9941 - val_loss: 0.0246 - val_accuracy: 0.9919 - 2s/epoch - 8ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.00971 to 0.00789, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0105 - accuracy: 0.9970 - val_loss: 0.0079 - val_accuracy: 0.9987 - 2s/epoch - 8ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0349 - val_accuracy: 0.9897 - 2s/epoch - 8ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.0091 - val_accuracy: 0.9982 - 2s/epoch - 8ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0069 - accuracy: 0.9980 - val_loss: 0.0109 - val_accuracy: 0.9982 - 2s/epoch - 8ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0092 - accuracy: 0.9979 - val_loss: 0.0189 - val_accuracy: 0.9942 - 2s/epoch - 8ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0148 - val_accuracy: 0.9973 - 2s/epoch - 8ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0017 - accuracy: 0.9994 - val_loss: 0.0112 - val_accuracy: 0.9982 - 2s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0512 - val_accuracy: 0.9879 - 2s/epoch - 8ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0161 - accuracy: 0.9957 - val_loss: 0.0191 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00789
# 279/279 - 2s - loss: 0.0079 - accuracy: 0.9982 - val_loss: 0.0092 - val_accuracy: 0.9973 - 2s/epoch - 8ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.00789 to 0.00678, saving model to ../models\best_model_fold_2.h5
# 279/279 - 2s - loss: 0.0028 - accuracy: 0.9991 - val_loss: 0.0068 - val_accuracy: 0.9991 - 2s/epoch - 8ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0021 - accuracy: 0.9994 - val_loss: 0.0199 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0091 - accuracy: 0.9973 - val_loss: 0.0137 - val_accuracy: 0.9960 - 2s/epoch - 8ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0038 - accuracy: 0.9990 - val_loss: 0.0174 - val_accuracy: 0.9969 - 2s/epoch - 8ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0073 - accuracy: 0.9984 - val_loss: 0.0081 - val_accuracy: 0.9982 - 2s/epoch - 8ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0098 - val_accuracy: 0.9987 - 2s/epoch - 8ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 5.7036e-04 - accuracy: 0.9999 - val_loss: 0.0085 - val_accuracy: 0.9991 - 2s/epoch - 8ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 8.6521e-04 - accuracy: 0.9998 - val_loss: 0.0081 - val_accuracy: 0.9991 - 2s/epoch - 8ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0012 - accuracy: 0.9996 - val_loss: 0.0271 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0037 - accuracy: 0.9993 - val_loss: 0.0091 - val_accuracy: 0.9987 - 2s/epoch - 8ms/step
# Epoch 40/100
# Restoring model weights from the end of the best epoch: 30.
#
# Epoch 40: val_loss did not improve from 0.00678
# 279/279 - 2s - loss: 0.0109 - accuracy: 0.9971 - val_loss: 0.0234 - val_accuracy: 0.9960 - 2s/epoch - 8ms/step
# Epoch 40: early stopping
# Score for fold 2: loss of 0.006777094677090645; accuracy of 99.91031289100647%
# Training for fold 3 ...
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.19745, saving model to ../models\best_model_fold_3.h5
# 279/279 - 3s - loss: 0.6708 - accuracy: 0.7591 - val_loss: 0.1974 - val_accuracy: 0.9229 - 3s/epoch - 11ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.19745 to 0.06477, saving model to ../models\best_model_fold_3.h5
# 279/279 - 2s - loss: 0.1736 - accuracy: 0.9405 - val_loss: 0.0648 - val_accuracy: 0.9794 - 2s/epoch - 8ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.06477 to 0.05707, saving model to ../models\best_model_fold_3.h5
# 279/279 - 2s - loss: 0.0726 - accuracy: 0.9776 - val_loss: 0.0571 - val_accuracy: 0.9780 - 2s/epoch - 8ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.05707 to 0.02481, saving model to ../models\best_model_fold_3.h5
# 279/279 - 2s - loss: 0.0422 - accuracy: 0.9887 - val_loss: 0.0248 - val_accuracy: 0.9919 - 2s/epoch - 8ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.02481 to 0.01825, saving model to ../models\best_model_fold_3.h5
# 279/279 - 2s - loss: 0.0236 - accuracy: 0.9939 - val_loss: 0.0182 - val_accuracy: 0.9946 - 2s/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.01825 to 0.01703, saving model to ../models\best_model_fold_3.h5
# 279/279 - 3s - loss: 0.0157 - accuracy: 0.9964 - val_loss: 0.0170 - val_accuracy: 0.9946 - 3s/epoch - 9ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.01703
# 279/279 - 2s - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.0176 - val_accuracy: 0.9960 - 2s/epoch - 9ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.01703
# 279/279 - 3s - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0573 - val_accuracy: 0.9794 - 3s/epoch - 9ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.01703
# 279/279 - 3s - loss: 0.0181 - accuracy: 0.9953 - val_loss: 0.0217 - val_accuracy: 0.9928 - 3s/epoch - 9ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.01703
# 279/279 - 3s - loss: 0.0181 - accuracy: 0.9951 - val_loss: 0.0288 - val_accuracy: 0.9901 - 3s/epoch - 10ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.01703
# 279/279 - 3s - loss: 0.0164 - accuracy: 0.9946 - val_loss: 0.0237 - val_accuracy: 0.9928 - 3s/epoch - 9ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.01703
# 279/279 - 2s - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.0360 - val_accuracy: 0.9910 - 2s/epoch - 8ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.01703 to 0.01089, saving model to ../models\best_model_fold_3.h5
# 279/279 - 2s - loss: 0.0142 - accuracy: 0.9967 - val_loss: 0.0109 - val_accuracy: 0.9978 - 2s/epoch - 9ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.01089
# 279/279 - 2s - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0189 - val_accuracy: 0.9960 - 2s/epoch - 8ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0077 - accuracy: 0.9975 - val_loss: 0.0133 - val_accuracy: 0.9964 - 3s/epoch - 9ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.01089
# 279/279 - 2s - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.0226 - val_accuracy: 0.9946 - 2s/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.01089
# 279/279 - 2s - loss: 0.0050 - accuracy: 0.9985 - val_loss: 0.0175 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0108 - accuracy: 0.9969 - val_loss: 0.0170 - val_accuracy: 0.9937 - 3s/epoch - 9ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0038 - accuracy: 0.9991 - val_loss: 0.0453 - val_accuracy: 0.9933 - 3s/epoch - 10ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0204 - accuracy: 0.9946 - val_loss: 0.0138 - val_accuracy: 0.9969 - 3s/epoch - 10ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0056 - accuracy: 0.9983 - val_loss: 0.0130 - val_accuracy: 0.9960 - 3s/epoch - 10ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.01089
# 279/279 - 3s - loss: 0.0098 - accuracy: 0.9973 - val_loss: 0.0179 - val_accuracy: 0.9964 - 3s/epoch - 9ms/step
# Epoch 23/100
# Restoring model weights from the end of the best epoch: 13.
#
# Epoch 23: val_loss did not improve from 0.01089
# 279/279 - 2s - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0174 - val_accuracy: 0.9951 - 2s/epoch - 9ms/step
# Epoch 23: early stopping
# Score for fold 3: loss of 0.010891015641391277; accuracy of 99.77578520774841%
# Training for fold 4 ...
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.19659, saving model to ../models\best_model_fold_4.h5
# 279/279 - 4s - loss: 0.5936 - accuracy: 0.7789 - val_loss: 0.1966 - val_accuracy: 0.9256 - 4s/epoch - 15ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.19659 to 0.08797, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.1617 - accuracy: 0.9427 - val_loss: 0.0880 - val_accuracy: 0.9695 - 3s/epoch - 9ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.08797 to 0.03752, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0711 - accuracy: 0.9769 - val_loss: 0.0375 - val_accuracy: 0.9888 - 3s/epoch - 9ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 0.03752
# 279/279 - 3s - loss: 0.0376 - accuracy: 0.9896 - val_loss: 0.0558 - val_accuracy: 0.9848 - 3s/epoch - 9ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.03752 to 0.02233, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0319 - accuracy: 0.9902 - val_loss: 0.0223 - val_accuracy: 0.9928 - 3s/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 0.02233
# 279/279 - 3s - loss: 0.0162 - accuracy: 0.9939 - val_loss: 0.0382 - val_accuracy: 0.9897 - 3s/epoch - 10ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.02233
# 279/279 - 2s - loss: 0.0162 - accuracy: 0.9952 - val_loss: 0.0360 - val_accuracy: 0.9919 - 2s/epoch - 9ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.02233
# 279/279 - 2s - loss: 0.0155 - accuracy: 0.9961 - val_loss: 0.0229 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 9/100
#
# Epoch 9: val_loss improved from 0.02233 to 0.02035, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0109 - accuracy: 0.9966 - val_loss: 0.0203 - val_accuracy: 0.9946 - 3s/epoch - 9ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.02035
# 279/279 - 3s - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0219 - val_accuracy: 0.9928 - 3s/epoch - 9ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.02035
# 279/279 - 3s - loss: 0.0080 - accuracy: 0.9983 - val_loss: 0.0846 - val_accuracy: 0.9812 - 3s/epoch - 9ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.02035
# 279/279 - 3s - loss: 0.0249 - accuracy: 0.9935 - val_loss: 0.0424 - val_accuracy: 0.9861 - 3s/epoch - 9ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 0.02035 to 0.01288, saving model to ../models\best_model_fold_4.h5
# 279/279 - 2s - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.0129 - val_accuracy: 0.9964 - 2s/epoch - 9ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 0.01288 to 0.01196, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0120 - val_accuracy: 0.9969 - 3s/epoch - 10ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.01196
# 279/279 - 2s - loss: 0.0105 - accuracy: 0.9973 - val_loss: 0.1434 - val_accuracy: 0.9722 - 2s/epoch - 9ms/step
# Epoch 16/100
#
# Epoch 16: val_loss did not improve from 0.01196
# 279/279 - 2s - loss: 0.0218 - accuracy: 0.9941 - val_loss: 0.0312 - val_accuracy: 0.9937 - 2s/epoch - 8ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.01196
# 279/279 - 2s - loss: 0.0102 - accuracy: 0.9969 - val_loss: 0.0209 - val_accuracy: 0.9942 - 2s/epoch - 8ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0069 - accuracy: 0.9982 - val_loss: 0.0261 - val_accuracy: 0.9942 - 3s/epoch - 9ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0070 - accuracy: 0.9978 - val_loss: 0.0141 - val_accuracy: 0.9960 - 3s/epoch - 9ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0020 - accuracy: 0.9994 - val_loss: 0.0171 - val_accuracy: 0.9964 - 3s/epoch - 9ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.0258 - val_accuracy: 0.9937 - 3s/epoch - 9ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0114 - accuracy: 0.9971 - val_loss: 0.0323 - val_accuracy: 0.9915 - 3s/epoch - 9ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.01196
# 279/279 - 3s - loss: 0.0158 - accuracy: 0.9960 - val_loss: 0.0122 - val_accuracy: 0.9960 - 3s/epoch - 9ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.01196 to 0.01003, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0035 - accuracy: 0.9989 - val_loss: 0.0100 - val_accuracy: 0.9969 - 3s/epoch - 9ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.01003 to 0.00977, saving model to ../models\best_model_fold_4.h5
# 279/279 - 3s - loss: 0.0022 - accuracy: 0.9993 - val_loss: 0.0098 - val_accuracy: 0.9964 - 3s/epoch - 11ms/step
# Epoch 26/100
#
# Epoch 26: val_loss improved from 0.00977 to 0.00965, saving model to ../models\best_model_fold_4.h5
# 279/279 - 2s - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.0097 - val_accuracy: 0.9964 - 2s/epoch - 8ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0144 - accuracy: 0.9959 - val_loss: 0.0912 - val_accuracy: 0.9839 - 3s/epoch - 9ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0126 - accuracy: 0.9969 - val_loss: 0.0183 - val_accuracy: 0.9946 - 3s/epoch - 9ms/step
# Epoch 29/100
#
# Epoch 29: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.0256 - val_accuracy: 0.9942 - 3s/epoch - 10ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.00965
# 279/279 - 2s - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.0133 - val_accuracy: 0.9973 - 2s/epoch - 9ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.00965
# 279/279 - 2s - loss: 7.3543e-04 - accuracy: 1.0000 - val_loss: 0.0171 - val_accuracy: 0.9969 - 2s/epoch - 8ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.00965
# 279/279 - 2s - loss: 0.0080 - accuracy: 0.9980 - val_loss: 0.0246 - val_accuracy: 0.9933 - 2s/epoch - 8ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 7.1174e-04 - accuracy: 0.9999 - val_loss: 0.0137 - val_accuracy: 0.9964 - 3s/epoch - 10ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0095 - accuracy: 0.9976 - val_loss: 0.1061 - val_accuracy: 0.9762 - 3s/epoch - 10ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0086 - accuracy: 0.9979 - val_loss: 0.0288 - val_accuracy: 0.9955 - 3s/epoch - 10ms/step
# Epoch 36/100
# Restoring model weights from the end of the best epoch: 26.
#
# Epoch 36: val_loss did not improve from 0.00965
# 279/279 - 3s - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0119 - val_accuracy: 0.9973 - 3s/epoch - 10ms/step
# Epoch 36: early stopping
# Score for fold 4: loss of 0.009654015302658081; accuracy of 99.64125752449036%
# Training for fold 5 ...
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 0.21662, saving model to ../models\best_model_fold_5.h5
# 279/279 - 4s - loss: 0.5908 - accuracy: 0.7748 - val_loss: 0.2166 - val_accuracy: 0.9098 - 4s/epoch - 14ms/step
# Epoch 2/100
#
# Epoch 2: val_loss improved from 0.21662 to 0.10095, saving model to ../models\best_model_fold_5.h5
# 279/279 - 2s - loss: 0.1637 - accuracy: 0.9409 - val_loss: 0.1009 - val_accuracy: 0.9672 - 2s/epoch - 8ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 0.10095 to 0.05732, saving model to ../models\best_model_fold_5.h5
# 279/279 - 2s - loss: 0.0725 - accuracy: 0.9769 - val_loss: 0.0573 - val_accuracy: 0.9803 - 2s/epoch - 9ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 0.05732 to 0.04635, saving model to ../models\best_model_fold_5.h5
# 279/279 - 2s - loss: 0.0404 - accuracy: 0.9874 - val_loss: 0.0463 - val_accuracy: 0.9865 - 2s/epoch - 9ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 0.04635 to 0.03885, saving model to ../models\best_model_fold_5.h5
# 279/279 - 3s - loss: 0.0274 - accuracy: 0.9917 - val_loss: 0.0388 - val_accuracy: 0.9865 - 3s/epoch - 9ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 0.03885 to 0.01940, saving model to ../models\best_model_fold_5.h5
# 279/279 - 2s - loss: 0.0172 - accuracy: 0.9952 - val_loss: 0.0194 - val_accuracy: 0.9933 - 2s/epoch - 8ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 0.01940
# 279/279 - 2s - loss: 0.0096 - accuracy: 0.9973 - val_loss: 0.0298 - val_accuracy: 0.9919 - 2s/epoch - 8ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0137 - accuracy: 0.9973 - val_loss: 0.0288 - val_accuracy: 0.9906 - 3s/epoch - 10ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0204 - accuracy: 0.9944 - val_loss: 0.0362 - val_accuracy: 0.9892 - 3s/epoch - 10ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0135 - accuracy: 0.9956 - val_loss: 0.0567 - val_accuracy: 0.9838 - 3s/epoch - 11ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0126 - accuracy: 0.9966 - val_loss: 0.0256 - val_accuracy: 0.9942 - 3s/epoch - 10ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0156 - accuracy: 0.9957 - val_loss: 0.0318 - val_accuracy: 0.9906 - 3s/epoch - 10ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0052 - accuracy: 0.9981 - val_loss: 0.0577 - val_accuracy: 0.9883 - 3s/epoch - 10ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 0.01940
# 279/279 - 3s - loss: 0.0187 - accuracy: 0.9947 - val_loss: 0.0329 - val_accuracy: 0.9928 - 3s/epoch - 10ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 0.01940
# 279/279 - 2s - loss: 0.0107 - accuracy: 0.9969 - val_loss: 0.0358 - val_accuracy: 0.9933 - 2s/epoch - 9ms/step
# Epoch 16/100
# Restoring model weights from the end of the best epoch: 6.
#
# Epoch 16: val_loss did not improve from 0.01940
# 279/279 - 2s - loss: 0.0133 - accuracy: 0.9961 - val_loss: 0.0488 - val_accuracy: 0.9865 - 2s/epoch - 9ms/step
# Epoch 16: early stopping
# Score for fold 5: loss of 0.019398966804146767; accuracy of 99.32705163955688%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 99.69% (+- 0.20)
# > Loss: 0.01
# ------------------------------------------------------------------------

# %% [markdown]
# ## Analysis of K-Fold Cross-Validation Results
#
# ### Summary of Results
# The model achieved an exceptionally high average accuracy of 99.67% with a very low standard deviation of 0.18% across all folds. This indicates a highly effective model with consistent performance across different subsets of the data. The average loss was remarkably low at 0.01, further confirming the model's efficacy in accurately predicting Alzheimer's Disease from the given features.
#
# ### Interpretation
# - **High Accuracy**: The high average accuracy suggests that the model is very effective at classifying the correct stages of Alzheimer's Disease. The low variability (standard deviation) in accuracy across folds underscores the model’s stability and robustness, which are crucial for clinical applications.
#
# - **Low Loss**: The minimal loss indicates that the model’s predictions are very close to the actual data, showcasing the model's ability to generalize well without overfitting.
#
# ### Conclusions
# These results validate the model's reliability and suitability for potentially aiding in the diagnostic process of Alzheimer's Disease. Given its high accuracy and low loss, it could be considered for further validation with external datasets or potentially in clinical trials to assess its practical utility in a real-world setting.
#
# The consistent performance across different data splits suggests that the model could reliably be used in diverse clinical scenarios without the risk of significant performance drops.

# %% [markdown]
# ## Saving the Final Model
#
# After completing the training and validation processes, and confirming the model's robust performance, it is essential to save the final model. This allows the model to be reused, deployed, or further evaluated without the need to retrain.
#
# ### Model Saving
# - The model is saved using TensorFlow's `save` method, which preserves not only the model architecture and weights but also its compilation information (including the optimizer, configured loss, and metrics).
# - Saving in TensorFlow's format ensures that the model can easily be reloaded in the exact state it was saved, facilitating both reproducibility and deployment.
#
# This step finalizes the modeling process, securely storing the trained model for future application.

# %%
# Define the path for saving the final model, use the .keras extension
final_model_path = os.path.join(models_dir, 'final_model_saved')

model.save(final_model_path)
# Out:
# INFO:tensorflow:Assets written to: ../models\final_model_saved\assets
# INFO:tensorflow:Assets written to: ../models\final_model_saved\assets

# %% [markdown]
# ## Feature Importance Analysis with SHAP
#
# Understanding the contribution of each feature to the model's predictions is crucial, especially in healthcare applications where interpretability can inform clinical decisions. We employ SHAP (SHapley Additive exPlanations), a game theory approach to explain the output of machine learning models.
#
# ### Explainer Setup
# - **Background Data**: A subset of the training data (`X_train`) is used to initialize the SHAP explainer. This subset is sampled to include 100 instances, providing a representative background for the model's data distribution.
# - **Explainer Initialization**: The `DeepExplainer` from SHAP is utilized, which is specifically designed for deep learning models. It leverages the background dataset to approximate the SHAP values.
#
# ### Calculate SHAP Values
# - **Subset Sampling**: SHAP values are computed for a randomly sampled subset of 100 instances from the test dataset (`X_test`). This approach ensures that the explanations are manageable and computationally feasible while still providing insight into the model's behavior on unseen data.
#
# ### Visualization of SHAP Values
# - **Summary Plot**: The SHAP summary plot provides a global view of the feature importances. It shows how much each feature contributes to increasing or decreasing the prediction output. The features are ranked by their importance, and their impact distribution across the dataset is displayed.
# - **Feature Names**: Custom feature names (`new_features`) are used in the plot to clearly identify each feature, enhancing the interpretability of the plot.
#
# This analysis not only highlights which features are most influential but also how they influence the model's predictions, adding an important layer of transparency to our predictive model.

# %%
# Explainer setup
background = shap.sample(X_train, 100) 
explainer = shap.DeepExplainer(model, background)

# Calculate SHAP values for a subset of the test data
shap_values = explainer.shap_values(shap.sample(X_test, 100))

# Visualize the SHAP values
shap.summary_plot(shap_values, shap.sample(X_test, 100), feature_names=new_features)
# Out:
# keras is no longer supported, please use tf.keras instead.
# Your TensorFlow version is newer than 2.4.0 and so graph support has been removed in eager mode and some static graphs may not be supported. See PR #1483 for discussion.
# `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.

# %% [markdown]
# ## Insights from SHAP Summary Plot
#
# The SHAP summary plot provides a visual representation of feature importances for the Alzheimer's Disease classification model. Each row corresponds to a feature, and the color-coded segments represent the impact of these features on the model's output across different classes.
#
# ### Key Observations
#
# - **Cognitive Test Scores**: Features such as `CDRSB.bl`, `MMSE.bl`, and `ADAS13.bl` are prominently placed at the top of the plot, indicating their significant influence on the model's predictions. These features, associated with cognitive test scores, are crucial for understanding the disease's impact on cognitive functions.
#
# - **Class-Differential Impact**: The spread of colors across the bars for each feature illustrates that the influence of certain features varies by class. For instance, `CDRSB.bl` shows a marked impact on Class 0 and Class 3, suggesting its relevance to the early and possibly intermediate stages of the disease.
#
# - **Biomarkers**: Anatomical features such as `Hippocampus.bl` and `Fusiform.bl` also demonstrate substantial importance. The hippocampus, known to be affected in Alzheimer's Disease, is validated by the model as a significant feature, aligning with current medical understanding.
#
# - **Variability in Influence**: The variability of feature impact across classes highlights the multifactorial nature of Alzheimer's Disease and reinforces the need for a nuanced approach to diagnosis and treatment.
#
# - **Potential for Clinical Application**: The diversity and strength of feature importance offer insights that could be leveraged for clinical applications, such as targeted screening and personalized treatment plans based on patient-specific profiles.
#
# ### Conclusion
#
# The model identifies a range of features with varying degrees of importance, reflecting the complex interplay of cognitive, genetic, and neuroanatomical factors in Alzheimer's Disease. This analysis underscores the potential of machine learning in enhancing our understanding and prediction of the disease, though clinical validation remains essential to ensure relevance and accuracy.

# %%
pip show tensorflow
# Out:
# Name: tensorflow
# Version: 2.13.0
# Summary: TensorFlow is an open source machine learning framework for everyone.
# Home-page: https://www.tensorflow.org/
# Author: Google Inc.
# Author-email: packages@tensorflow.org
# License: Apache 2.0
# Location: c:\users\royri\anaconda3\envs\adni_env\lib\site-packages
# Requires: tensorflow-intel
# Required-by:
# Note: you may need to restart the kernel to use updated packages.
